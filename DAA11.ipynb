# %%
# a------b
# |      |
# |      |
# c------d------e

# %%
# create the dictionary with graph elements
graph = { "a" : ["b","c"],
         "b" : ["a","d"],
         "c" : ["a","d"],
         "d" : ["e"],
         "e" :["d"]
         }

         # print the graph
print(graph)
# Out:
# {'a': ['b', 'c'], 'b': ['a', 'd'], 'c': ['a', 'd'], 'd': ['e'], 'e': ['d']}

# %%
# Latihan #
# T---u---v
# |       |
# w-------X
# |       |
# Z       S

# %%
# create the dictionary with graph elements
graph = { "T" : ["V","W"],
         "U" : ["V","T"],
         "V" : ["T","X"],
         "W" : ["Z","X","T"],
         "X" : ["S","W","V"],
         "Z" :["W"],
         "S" :["X"]
         }

         # print the graph
print(graph)
# Out:
# {'T': ['V', 'W'], 'U': ['V', 'T'], 'V': ['T', 'X'], 'W': ['Z', 'X', 'T'], 'X': ['S', 'W', 'V'], 'Z': ['W'], 'S': ['X']}

# %%
# Latihan #
# R-----O-----M
# |     |     |
# L-----P-----M

# %%
# create the dictionary with graph elements
graph = { "r" : ["o","l"],
          "o" : ["r","p","m"],
          "m" : ["o","n"],
          "l" : ["r","p"],
          "p" : ["l","o","n"],
          "n" : ["p","m"]
         }

         # print the graph
print(graph)
# Out:
# {'r': ['o', 'l'], 'o': ['r', 'p', 'm'], 'm': ['o', 'n'], 'l': ['r', 'p'], 'p': ['l', 'o', 'n'], 'n': ['p', 'm']}

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
          gdict = []
        self.gdict = gdict

# Get the keys of the dictionary
    def getVertices (self):
        return list (self.gdict.keys())
# Create the dictionary with graph elements 
graph_elements ={ "a" : ["b","c"],
                "b" : ["a", "d"],
                "c" : ["a", "d"],
                "d" : ["e"],
                "e" : ["d"]
                }

g = graph(graph_elements)

print(g.getVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
# Latihan
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
          gdict = []
        self.gdict = gdict

# Get the keys of the dictionary
    def getVertices (self):
        return list (self.gdict.keys())
# Create the dictionary with graph elements 
graph_elements ={ "T" : ["V","W"],
                  "U" : ["V","T"],
                  "V" : ["T","X"],
                  "W" : ["Z","X","T"],
                  "X" : ["S","W","V"],
                  "Z" :["W"],
                  "S" :["X"]
         }

g = graph(graph_elements)

print(g.getVertices())
# Out:
# ['T', 'U', 'V', 'W', 'X', 'Z', 'S']

# %%
# Latihan
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
          gdict = []
        self.gdict = gdict

# Get the keys of the dictionary
    def getVertices (self):
        return list (self.gdict.keys())
# Create the dictionary with graph elements 
graph_elements ={ "r" : ["o","l"],
          "o" : ["r","p","m"],
          "m" : ["o","n"],
          "l" : ["r","p"],
          "p" : ["l","o","n"],
          "n" : ["p","m"]
         }

g = graph(graph_elements)

print(g.getVertices())
# Out:
# ['r', 'o', 'm', 'l', 'p', 'n']

# %%
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges (self): 
        return self.findedges()

# Find the distinct List of edges
    def findedges(self):
        edgename = [] 
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

# Create the dictionary with graph elements
graph_elements= {"a" : ["b","c"],
                 "b" : ["a", "d"],
                 "c" : ["a", "d"],
                 "d" : ["e"],
                 "e" : ["d"]
                }

g = graph(graph_elements)

print(g.edges())
# Out:
# [{'b', 'a'}, {'c', 'a'}, {'b', 'd'}, {'c', 'd'}, {'e', 'd'}]

# %%
# Latihan #
class graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict

    def edges (self): 
        return self.findedges()

# Find the distinct List of edges
    def findedges(self):
        edgename = [] 
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

# Create the dictionary with graph elements
graph_elements= { "S" :["X"],
                  "T" : ["V","W"],
                  "U" : ["V","T"],
                  "V" : ["T","X"],
                  "W" : ["Z","X","T"],
                  "X" : ["S","W","V"],
                  "Z" :["W"]
                }

g = graph(graph_elements)

print(g.edges())
# Out:
# [{'X', 'S'}, {'V', 'T'}, {'T', 'W'}, {'V', 'U'}, {'T', 'U'}, {'V', 'X'}, {'W', 'Z'}, {'X', 'W'}]

# %%
class graph:
  
    def __init__ (self,gdict=None):
        if gdict is None:
            gdict = {} 
        self.gdict = gdict

    def getVertices (self):
        return list (self.gdict.keys())

# Add the vertex as a key
    def addVertex (self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = [] 
# Create the dictionary with grapeleape Lements
graph_elements = {"a": ["b","c"],
                "b" : ["a","d"],
                "c" : ["a","d"],
                "d" : ["e"], 
                "e" : ["d"]
              }

g = graph (graph_elements)
g.addVertex ("f")
print (g.getVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
class graph:
  
    def __init__ (self,gdict=None):
        if gdict is None:
            gdict = {} 
        self.gdict = gdict

    def getVertices (self):
        return list (self.gdict.keys())

# Add the vertex as a key
    def addVertex (self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = [] 
# Create the dictionary with grapeleape Lements
graph_elements = { "r" : ["o","l"],
          "o" : ["r","p","m"],
          "m" : ["o","n"],
          "l" : ["r","p"],
          "p" : ["l","o","n"],
          "n" : ["p","m"]
         }

g = graph (graph_elements)
g.addVertex ("x")
print (g.getVertices())
# Out:
# ['r', 'o', 'm', 'l', 'p', 'n', 'x']

# %%
class graph:

    def __init__ (self,gdict=None): 
        if gdict is None:
            gdict = {}
        self.gdict = gdict
        
    def edges(self):
        return self.findedges() 
# Add the new edge

    def AddEdge (self, edge):
        edge = set(edge)
        (vrtx1, vrtx2) = tuple(edge)
        if vrtx1 in self.gdict:
            self.gdict[vrtx1].append(vrtx2)
        else:
            self.gdict[vrtx1] = [vrtx2]

# List the edge names 
    def findedges (self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

# %%
# create the dictionary with graph elements
graph_elements = { "a" : ["b","c"],
                  "b" : ["a","d"],
                  "c" : ["a","d"],
                  "d" : ["e"],
                  "e" :["d"]
                  }

g = graph(graph_elements)
g.AddEdge({'a','e'})
g.AddEdge({'a','c'})
print(g.edges())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-3045dd772b86> in <module>()
#       7                   }
#       8
# ----> 9 g = graph(graph_elements)
#      10 g.AddEdge({'a','e'})
#      11 g.AddEdge({'a','c'})
#
# TypeError: 'dict' object is not callable
